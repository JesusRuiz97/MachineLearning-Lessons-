# %% [markdown]
# # Pandas - Ficheros HTML

# %%
import numpy as np
import pandas as pd

# %%
pagina_web = 'https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n'

# %%
datos = pd.read_html(pagina_web)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 datos = pd.read_html(pagina_web)
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
# ...

# %% [markdown]
# ### Procedo a Instalar 'urllib' ya que este no se menciona en el ejercicio.

# %%
import urllib.request

# %%
pagina_web = 'https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n'

# %%
datos = pd.read_html(pagina_web)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 datos = pd.read_html(pagina_web)
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
# ...

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
req = urllib.request.Request(pagina_web, headers=headers)

# %%
with urllib.request.urlopen(req) as response:
        html_content = response.read()

# %%
datos = pd.read_html(html_content)

# %%
type(datos)
# Out:
# list

# %%
dataframe = datos[0]

# %%
dataframe.head(10)
# Out:
#   N.º País (o territorio dependiente)  \
# 0   1                           India
# 1   2                      China[12]​
# 2   3                  Estados Unidos
# 3   4                       Indonesia
# 4   5                        Pakistán
# 5   6                         Nigeria
# 6   7                          Brasil
# 7   8                       Bangladés
# 8   9                      Rusia[13]​
# 9  10                          México
#
#   Proyección exponencial de la población al 1/7/2025[7]​ Total mun- dial (%)  \
# 0                                      1 417 492 000                    1754
# 1                                      1 407 934 000                    1742
# 2                                        342 181 000                     423
# 3                                        284 447 000                     352
# 4                                        256 204 000                     317
# ...
