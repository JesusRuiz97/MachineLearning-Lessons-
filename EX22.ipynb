# %%
import numpy as np
import pandas as pd

# %%
ventas_enero = np.random.randint(100,500,3)

# %%
ventas_enero
# Out:
# array([404, 371, 309], dtype=int32)

# %%
ventas_febrero = np.random.randint(100,500,3)

# %%
ventas_febrero
# Out:
# array([312, 234, 360], dtype=int32)

# %%
ventas_marzo = np.random.randint(100,500,3)

# %%
ventas_marzo
# Out:
# array([414, 163, 280], dtype=int32)

# %%
filas = ['ventas_enero', 'ventas_febrero', 'ventas_marzo']

# %%
filas
# Out:
# ['ventas_enero', 'ventas_febrero', 'ventas_marzo']

# %%
columnas = ['oficina_1', 'oficina_2', 'oficina_3']

# %%
columnas
# Out:
# ['oficina_1', 'oficina_2', 'oficina_3']

# %%
ventas = [ventas_enero, ventas_febrero, ventas_marzo]

# %%
ventas
# Out:
# [array([404, 371, 309], dtype=int32),
#  array([312, 234, 360], dtype=int32),
#  array([414, 163, 280], dtype=int32)]

# %%
dataframe = pd.DataFrame(ventas,filas,columnas)

# %%
dataframe
# Out:
#                 oficina_1  oficina_2  oficina_3
# ventas_enero          404        371        309
# ventas_febrero        312        234        360
# ventas_marzo          414        163        280

# %%
ventas_enero_oficina_1 = dataframe['oficina_1']['ventas_enero']

# %%
ventas_enero_oficina_1
# Out:
# np.int32(404)

# %%
print("Las ventas de la oficina_1 son de {}".format(ventas_enero_oficina_1))
# Out:
# Las ventas de la oficina_1 son de 404
