# %% [markdown]
# ### DataFrames : Seleccion de datos con una condicion

# %%
import pandas as pd
import numpy as np

# %%
filas = 'ventas1 ventas2 ventas3'.split()
filas
# Out:
# ['ventas1', 'ventas2', 'ventas3']

# %%
columnas = 'zonaA zonaB zonaC'.split()
columnas
# Out:
# ['zonaA', 'zonaB', 'zonaC']

# %%
datos = [ [120,340,250], [210,450,250], [310,210,140] ]
datos
# Out:
# [[120, 340, 250], [210, 450, 250], [310, 210, 140]]

# %%
dataframe = pd.DataFrame(datos,filas,columnas)

# %%
dataframe
# Out:
#          zonaA  zonaB  zonaC
# ventas1    120    340    250
# ventas2    210    450    250
# ventas3    310    210    140

# %%
condicion = dataframe > 200

# %%
dataframe[condicion]
# Out:
#          zonaA  zonaB  zonaC
# ventas1    NaN    340  250.0
# ventas2  210.0    450  250.0
# ventas3  310.0    210    NaN

# %%
dataframe
# Out:
#          zonaA  zonaB  zonaC
# ventas1    120    340    250
# ventas2    210    450    250
# ventas3    310    210    140

# %%
condicion = dataframe['zonaA'] > 200
dataframe[condicion]
# Out:
#          zonaA  zonaB  zonaC
# ventas2    210    450    250
# ventas3    310    210    140

# %%
dataframe
# Out:
#          zonaA  zonaB  zonaC
# ventas1    120    340    250
# ventas2    210    450    250
# ventas3    310    210    140

# %%
condicion = (dataframe['zonaA'] > 200) | (dataframe['zonaB'] > 300)
dataframe[condicion]
# Out:
#          zonaA  zonaB  zonaC
# ventas1    120    340    250
# ventas2    210    450    250
# ventas3    310    210    140

# %%
dataframe[condicion][['zonaB','zonaC']]
# Out:
#          zonaB  zonaC
# ventas1    340    250
# ventas2    450    250
# ventas3    210    140
