# %% [markdown]
# ### DataFrame : Modificacion de los nombres de las filas

# %%
import numpy as np
import pandas as pd

# %%
filas = 'ventas1 ventas2 ventas3'.split()
columnas = 'zonaA zonaB zonaC'.split()
datos = [[100,200,250], [210,300,425], [250,310,124]]
dataframe = pd.DataFrame(datos, filas, columnas)

# %%
dataframe
# Out:
#          zonaA  zonaB  zonaC
# ventas1    100    200    250
# ventas2    210    300    425
# ventas3    250    310    124

# %%
nuevas_filas = 'dia1 dia2 dia3'.split()
nuevas_filas
# Out:
# ['dia1', 'dia2', 'dia3']

# %%
dataframe['dias'] = nuevas_filas
dataframe
# Out:
#          zonaA  zonaB  zonaC  dias
# ventas1    100    200    250  dia1
# ventas2    210    300    425  dia2
# ventas3    250    310    124  dia3

# %%
dataframe.set_index('dias')
# Out:
#       zonaA  zonaB  zonaC
# dias
# dia1    100    200    250
# dia2    210    300    425
# dia3    250    310    124

# %%
dataframe
# Out:
#          zonaA  zonaB  zonaC  dias
# ventas1    100    200    250  dia1
# ventas2    210    300    425  dia2
# ventas3    250    310    124  dia3

# %%
dataframe = dataframe.set_index('dias')

# %%
dataframe
# Out:
#       zonaA  zonaB  zonaC
# dias
# dia1    100    200    250
# dia2    210    300    425
# dia3    250    310    124
