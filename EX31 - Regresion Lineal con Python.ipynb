# %% [markdown]
# # Regresion Lineal con Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\Vaquita'

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 462B-5518
#
#  Directorio de C:\Users\Vaquita
#
# 10/11/2025  10:59    <DIR>          .
# 10/11/2025  10:59    <DIR>          ..
# 05/09/2024  16:42    <DIR>          .anaconda
# 04/08/2025  03:22    <DIR>          .android
# 10/11/2025  11:00    <DIR>          .conda
# 10/11/2025  09:40               103 .condarc
# 31/03/2025  17:44    <DIR>          .config
# 05/09/2024  15:15    <DIR>          .continuum
# 10/11/2025  10:30    <DIR>          .cufflinks
# 25/04/2025  02:55    <DIR>          .cursor
# 04/08/2025  03:14    <DIR>          .gradle
# 10/11/2025  10:56    <DIR>          .ipynb_checkpoints
# 05/09/2024  15:34    <DIR>          .ipython
# 13/01/2025  14:31    <DIR>          .jupyter
# 31/03/2025  17:45    <DIR>          .m2
# 05/11/2025  18:04    <DIR>          .matplotlib
# 01/04/2025  00:51    <DIR>          .openjfx
# 04/08/2025  03:17    <DIR>          .skiko
# 13/02/2025  18:14               284 .Untitled5.ipynb.layout
# 14/02/2025  15:56    <DIR>          .virtual_documents
# 22/08/2024  20:44             6.579 -1.14-windows.xml
# 24/07/2025  04:32            61.119 2424.fst
# 29/03/2024  02:39    <DIR>          3D Objects
# 09/02/2025  02:56         2.234.044 AMD_RyzenMaster.log
# 09/02/2025  02:56             8.827 AMDRM_Install.log
# 31/10/2025  13:29    <DIR>          anaconda_projects
# 03/11/2025  11:21    <DIR>          anaconda3
# 04/08/2025  03:13    <DIR>          AndroidStudioProjects
# 31/10/2025  16:06             2.741 array.ipynb
# 29/03/2024  02:39    <DIR>          Contacts
# 13/10/2024  15:31    <DIR>          curseforge
# 10/11/2025  10:59    <DIR>          Desktop
# 08/11/2025  13:51    <DIR>          Documents
# 10/11/2025  10:58    <DIR>          Downloads
# 05/11/2025  12:21             5.508 Ejemplo_excel.xlsx
# 31/10/2025  13:58             2.384 EX1.ipynb
# 03/11/2025  14:12            11.727 EX11 - Pandas Tratamiento datos nulos o sin valor.ipynb
# 03/11/2025  16:52             9.495 EX13 - Merge DataFrames.ipynb
# 03/11/2025  16:47             9.574 EX14 - Pandas - Combinar DataFrames.ipynb
# 03/11/2025  16:59             6.870 EX15 - Join DataFrames(Pandas).ipynb
# 03/11/2025  17:14            15.716 EX16 - Operaciones (Pandas).ipynb
# 05/11/2025  13:12            12.355 EX17 - Pandas Ficheros Excel .ipynb
# 05/11/2025  16:13            55.629 EX18 - Pandas Ficheros HTML.ipynb
# 05/11/2025  17:51             5.109 EX19 - Pandas SQL.ipynb
# 31/10/2025  14:44             2.571 EX2.ipynb
# 05/11/2025  18:16           414.056 EX20 - Graphics with Pandas.ipynb
# 05/11/2025  18:30             3.544 EX21.ipynb
# 05/11/2025  18:38             7.696 EX22.ipynb
# 06/11/2025  13:38           278.511 EX23 - Matplotlib.ipynb
# 06/11/2025  12:45            52.312 EX24.ipynb
# 06/11/2025  14:17           519.026 EX25 - Seaborn.ipynb
# 06/11/2025  14:23           282.138 EX26 - Graficos para Categorias Seaborn.ipynb
# 06/11/2025  14:29           128.080 EX27 - Heatmaps Seaborn.ipynb
# 10/11/2025  08:52           695.631 EX28 Graficos de cuadricula (Grids) PairGrid y FacetGrid.ipynb
# 10/11/2025  09:08           493.917 EX29 - Gráficos de regresión (Regression Plots).ipynb
# 31/10/2025  15:38             2.559 EX3.ipynb
# 10/11/2025  09:17            59.552 EX30 - Estilos y Colores Seaborn.ipynb
# 10/11/2025  10:58             1.065 EX31 - Regresion Lineal con Python.ipynb
# 31/10/2025  15:46             2.030 EX4.ipynb
# 31/10/2025  17:01             2.558 EX5.ipynb
# 31/10/2025  17:07             2.404 EX6.ipynb
# 03/11/2025  11:47             4.986 EX7.ipynb
# 03/11/2025  12:30            21.261 EX8 - DataFrames.ipynb
# 03/11/2025  12:44            15.318 EX9 - DataFrame Condiciones.ipynb
# 05/11/2025  18:23            11.684 EX9 - DataFrame Modificacion de los nombres de las filas.ipynb
# 06/11/2025  13:48             5.238 Exam - Matplotlib 2.ipynb
# 06/11/2025  13:50             5.086 Exam - Matplotlib 3.ipynb
# 29/03/2024  02:39    <DIR>          Favorites
# 13/02/2025  18:06               760 First steps with Jupyter.ipynb
# 29/03/2024  02:39    <DIR>          Links
# 25/08/2024  16:47    <DIR>          Music
# 05/09/2024  15:39             1.802 My first Program.ipynb
# 06/09/2024  12:57    <DIR>          My First Project in Jupyter
# 19/07/2024  16:57    <DIR>          Noire
# 13/09/2024  03:20    <DIR>          OneDrive
# 03/11/2025  14:32             8.823 Pandas - Agrupacion de datos.ipynb
# 16/09/2025  11:31    <DIR>          Pictures
# 14/02/2025  15:58    <DIR>          Recipes
# 05/11/2025  13:11             5.108 salida_excel.xlsx
# 01/08/2025  03:34    <DIR>          Saved Games
# 29/03/2024  02:40    <DIR>          Searches
# 08/09/2024  13:23    <DIR>          source
# 31/10/2025  16:47             5.013 test3.ipynb
# 31/10/2025  16:52             8.485 test7.ipynb
# 31/10/2025  16:18            12.198 testing.ipynb
# 31/10/2025  16:20             4.860 testing2.ipynb
# 25/09/2019  08:26           726.209 USA_Housing.csv
# 17/09/2025  11:15    <DIR>          Videos
# 23/04/2025  17:14        27.009.872 worldpainter_2.24.0.exe
#               50 archivos     33.242.417 bytes
#               39 dirs  321.299.374.080 bytes libres

# %%
casas = pd.read_csv('USA_Housing.csv')

# %%
casas
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
casas.head(20)
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.458574             5.682861                   7.009188
# 1       79248.642455             6.002900                   6.730821
# 2       61287.067179             5.865890                   8.512727
# 3       63345.240046             7.188236                   5.586729
# 4       59982.197226             5.040555                   7.839388
# 5       80175.754159             4.988408                   6.104512
# 6       64698.463428             6.025336                   8.147760
# 7       78394.339278             6.989780                   6.620478
# 8       59927.660813             5.362126                   6.393121
# 9       81885.927184             4.423672                   8.167688
# 10      80527.472083             8.093513                   5.042747
# 11      50593.695497             4.496513                   7.467627
# 12      39033.809237             7.671755                   7.250029
# 13      73163.663441             6.919535                   5.993188
# 14      69391.380184             5.344776                   8.406418
# 15      73091.866746             5.443156                   8.517513
# 16      79706.963058             5.067890                   8.219771
# 17      61929.077018             4.788550                   5.097010
# 18      63508.194299             5.947165                   7.187774
# 19      62085.276403             5.739411                   7.091808
#
#     Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                           4.09     23086.800503  1.059034e+06
# 1                           3.09     40173.072174  1.505891e+06
# 2                           5.13     36882.159400  1.058988e+06
# 3                           3.26     34310.242831  1.260617e+06
# 4                           4.23     26354.109472  6.309435e+05
# 5                           4.04     26748.428425  1.068138e+06
# 6                           3.41     60828.249085  1.502056e+06
# 7                           2.42     36516.358972  1.573937e+06
# 8                           2.30     29387.396003  7.988695e+05
# 9                           6.10     40149.965749  1.545155e+06
# 10                          4.10     47224.359840  1.707046e+06
# 11                          4.49     34343.991886  6.637324e+05
# 12                          3.10     39220.361467  1.042814e+06
# 13                          2.27     32326.123139  1.291332e+06
# 14                          4.37     35521.294033  1.402818e+06
# 15                          4.01     23929.524053  1.306675e+06
# 16                          3.12     39717.813576  1.556787e+06
# 17                          4.30     24595.901498  5.284852e+05
# 18                          5.12     35719.653052  1.019426e+06
# 19                          5.49     44922.106702  1.030591e+06
#
#                                               Address
# 0   208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1   188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2   9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                           USS Barnett\nFPO AP 44820
# 4                          USNS Raymond\nFPO AE 09386
# 5   06039 Jennifer Islands Apt. 443\nTracyport, KS...
# 6   4759 Daniel Shoals Suite 442\nNguyenburgh, CO ...
# 7      972 Joyce Viaduct\nLake William, TN 17778-6483
# 8                           USS Gilbert\nFPO AA 20957
# 9                    Unit 9446 Box 0958\nDPO AE 97025
# 10  6368 John Motorway Suite 700\nJanetbury, NM 26854
# 11  911 Castillo Park Apt. 717\nDavisborough, PW 7...
# 12  209 Natasha Stream Suite 961\nHuffmanland, NE ...
# 13  829 Welch Track Apt. 992\nNorth John, AR 26532...
# 14                   PSC 5330, Box 4420\nAPO AP 08302
# 15     2278 Shannon View\nNorth Carriemouth, NM 84617
# 16   064 Hayley Unions\nNicholsborough, HI 44161-1887
# 17      5498 Rachel Locks\nNew Gregoryshire, PW 54755
# 18                   Unit 7424 Box 2786\nDPO AE 71255
# 19    19696 Benjamin Cape\nStephentown, ME 36952-4733

# %%
casas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
casas.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
casas.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
casas['Avg. Area Number of Rooms']
# Out:
# 0       7.009188
# 1       6.730821
# 2       8.512727
# 3       5.586729
# 4       7.839388
#           ...
# 4995    6.137356
# 4996    6.576763
# 4997    4.805081
# 4998    7.130144
# 4999    6.792336
# Name: Avg. Area Number of Rooms, Length: 5000, dtype: float64

# %%
sns.distplot(casas['Price'])
# Out:
# C:\Users\Vaquita\AppData\Local\Temp\ipykernel_7316\2761978606.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(casas['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.heatmap(casas.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.heatmap(casas.corr())
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~\anaconda3\envs\base2\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: '208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101'

# %%
sns.heatmap(casas.corr(numeric_only=True), annot=True)
#Solucion(No explicada en el curso)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
casas.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
casas.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
X = casas[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]

# %%
Y = casas['Price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
lrm = LinearRegression()
lrm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
predicciones = lrm.predict(X_test)

# %%
predicciones
# Out:
# array([1308536.1359262 , 1237122.72746477, 1243835.62817066, ...,
#        1457119.79297242, 1483428.9530937 , 1047510.59737176],
#       shape=(1500,))

# %%
Y_test
# Out:
# 1501    1.339096e+06
# 2586    1.251794e+06
# 2653    1.340095e+06
# 1055    1.431508e+06
# 705     1.042374e+06
#             ...
# 3563    1.348222e+06
# 1538    1.309937e+06
# 1837    1.472887e+06
# 2380    1.409762e+06
# 1912    1.009606e+06
# Name: Price, Length: 1500, dtype: float64

# %%
plt.scatter(Y_test, predicciones)

# %%
sns.distplot(Y_test - predicciones)
# Out:
# C:\Users\Vaquita\AppData\Local\Temp\ipykernel_7316\320386886.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test - predicciones)
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# **MAE (Mean absolute error) - (Media del valor absoluto de los errores)**

# %%
metrics.mean_absolute_error(Y_test, predicciones)
# Out:
# 81135.56609336875

# %% [markdown]
# **MSE (media de los errores al cuadrado)**

# %%
metrics.mean_squared_error(Y_test, predicciones)
# Out:
# 10068422551.401081

# %% [markdown]
# **RMSE**

# %%
np.sqrt(metrics.mean_squared_error(Y_test, predicciones))
# Out:
# np.float64(100341.52954485537)
